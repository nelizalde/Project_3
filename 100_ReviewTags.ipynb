# %%
import os
import csv

# %%
import pandas as pd

# %%
file=pd.read_csv("Column_Tags.csv")

# %%
csvpath ="Column_Tags.csv"

# %%
with open(csvpath) as csvfile:

    # CSV reader specifies delimiter and variable that holds contents
    csvreader = csv.reader(csvfile, delimiter=',')
    
    print(csvreader)
    
    csv_header = next(csvreader)
    print(f"CSV Header: {csv_header}")

    for row in csvreader:
        print(row)
# Out:
# ...
# CSV Header: ['ï»¿tags', '', '', '', '', '', '', '']
# ["[' Business trip ', ' Solo traveler ', ' Double Room ', ' Stayed 2 nights ', ' Submitted from a mobile device ']", '', '', '', '', '', '', '']
# ["[' Leisure trip ', ' Couple ', ' Double Hilton Deluxe Room ', ' Stayed 1 night ']", '', '', '', '', '', '', '']
# ["[' Leisure trip ', ' Group ', ' Double or Twin Room ', ' Stayed 3 nights ']", '', '', '', '', '', '', '']
# ["[' Leisure trip ', ' Couple ', ' Executive Twin Room with Access to The Level Lounge ', ' Stayed 5 nights ']", '', '', '', '', '', '', '']
# ["[' Business trip ', ' Solo traveler ', ' Standard Room ', ' Stayed 2 nights ']", '', '', '', '', '', '', '']
# ["[' Leisure trip ', ' Family with older children ', ' Deluxe Double and Single Room ', ' Stayed 3 nights ']", '', '', '', '', '', '', '']
# ["[' Leisure trip ', ' Couple ', ' Standard Double Room ', ' Stayed 2 nights ', ' Submitted from a mobile device ']", '', '', '', '', '', '', '']
# ...

# %%
#Return a Data Frame 
tags_df = pd.read_csv(csvpath)
tags_df.head()
# Out:
#                                                 tags  Unnamed: 1  Unnamed: 2  \
# 0  [' Business trip ', ' Solo traveler ', ' Doubl...         NaN         NaN
# 1  [' Leisure trip ', ' Couple ', ' Double Hilton...         NaN         NaN
# 2  [' Leisure trip ', ' Group ', ' Double or Twin...         NaN         NaN
# 3  [' Leisure trip ', ' Couple ', ' Executive Twi...         NaN         NaN
# 4  [' Business trip ', ' Solo traveler ', ' Stand...         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN

# %%
new_tags_df=tags_df[["tags"]].copy()
new_tags_df
# Out:
#                                                  tags
# 0   [' Business trip ', ' Solo traveler ', ' Doubl...
# 1   [' Leisure trip ', ' Couple ', ' Double Hilton...
# 2   [' Leisure trip ', ' Group ', ' Double or Twin...
# 3   [' Leisure trip ', ' Couple ', ' Executive Twi...
# 4   [' Business trip ', ' Solo traveler ', ' Stand...
# ..                                                ...
# 94  [' Leisure trip ', ' Couple ', ' Superior Doub...
# 95  [' Leisure trip ', ' Couple ', ' Deluxe Room 1...
# 96  [' Leisure trip ', ' Couple ', ' Double Room '...
# 97  [' Family with young children ', ' Triple Room...
# 98  [' Leisure trip ', ' Solo traveler ', ' Double...
#
# [99 rows x 1 columns]

# %%
new_tags_df["words1"]=new_tags_df["tags"].map(lambda list:list[1:-2].split(",")[0])
new_tags_df["words2"]=new_tags_df["tags"].map(lambda list:list[1:-2].split(",")[1])
new_tags_df["words3"]=new_tags_df["tags"].map(lambda list:list[1:-2].split(",")[2])
new_tags_df["words4"]=new_tags_df["tags"].map(lambda list:list[1:-2].split(",")[-1])
new_tags_df["words1"]=new_tags_df.loc[new_tags_df["words1"].str.contains("trip"),"words1"]
new_tags_df
# Out:
#                                                  tags             words1  \
# 0   [' Business trip ', ' Solo traveler ', ' Doubl...  ' Business trip '
# 1   [' Leisure trip ', ' Couple ', ' Double Hilton...   ' Leisure trip '
# 2   [' Leisure trip ', ' Group ', ' Double or Twin...   ' Leisure trip '
# 3   [' Leisure trip ', ' Couple ', ' Executive Twi...   ' Leisure trip '
# 4   [' Business trip ', ' Solo traveler ', ' Stand...  ' Business trip '
# ..                                                ...                ...
# 94  [' Leisure trip ', ' Couple ', ' Superior Doub...   ' Leisure trip '
# 95  [' Leisure trip ', ' Couple ', ' Deluxe Room 1...   ' Leisure trip '
# 96  [' Leisure trip ', ' Couple ', ' Double Room '...   ' Leisure trip '
# 97  [' Family with young children ', ' Triple Room...                NaN
# 98  [' Leisure trip ', ' Solo traveler ', ' Double...   ' Leisure trip '
#
#                 words2                                             words3  \
# ...

# %%
trip_count = new_tags_df["words1"].value_counts()
trip_count
# Out:
# ' Leisure trip '     80
# ' Business trip '    14
# Name: words1, dtype: int64

# %%
guest_count = new_tags_df["words2"].value_counts()
guest_count=guest_count[count>5]

# %%
pd.DataFrame(count[count>5])
# Out:
#                                  words2
#  ' Couple '                          41
#  ' Family with young children '      18
#  ' Solo traveler '                   18
#  ' Group '                           10

# %%
(trip_count.append(guest_count)).to_csv("Temp.csv")
